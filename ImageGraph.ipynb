# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisBox/ImGraph/blob/master/ImageGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # Remember to install the imagegraph Python library thus:
# !pip install git+https://github.com/leoimpett/pyimagegraph
import imagegraph as ig
imL03 = ig.loadIIIFManifest("https://cudl.lib.cam.ac.uk/iiif/PH-Y-30469-F-GN.json") 
vL00 = ig.getNNEmbedding(imL03) 
fL01,fL02 = ig.reduceDims(vL00) 
_ = ig.scatterImages(imL03,fL01,fL02)
# Out:
# Collecting git+https://github.com/leoimpett/pyimagegraph
#   Cloning https://github.com/leoimpett/pyimagegraph to /tmp/pip-req-build-t7bwd35l
#   Running command git clone -q https://github.com/leoimpett/pyimagegraph /tmp/pip-req-build-t7bwd35l
# Requirement already satisfied (use --upgrade to upgrade): imagegraph==0.0.1 from git+https://github.com/leoimpett/pyimagegraph in /usr/local/lib/python3.6/dist-packages
# Building wheels for collected packages: imagegraph
#   Building wheel for imagegraph (setup.py) ... done
#   Created wheel for imagegraph: filename=imagegraph-0.0.1-cp36-none-any.whl size=26424 sha256=934b5da3d15e4bd62db9436c35987575ee9a3cd4ab6123668140c26a7d7c2e4d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e27gu1hg/wheels/7b/78/0e/fae6d5b313f1b1e04d581776fa9cd17893a07e3a07d6a8b028
# Successfully built imagegraph
# downloading images from IIIF manifest...
# 100%|██████████| 63/63 [01:11<00:00,  1.13s/it]
# Neural network weights already downloaded, extracting...
# 100%|██████████| 63/63 [00:17<00:00,  3.81it/s]
# 100%|██████████| 63/63 [00:00<00:00, 479.52it/s]
# plotting images...
