# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisBox/ImGraph/blob/master/ImageGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # Remember to install the imagegraph Python library thus:
# !pip install git+https://github.com/leoimpett/pyimagegraph
import imagegraph as ig
imL03 = ig.loadIIIFManifest("https://cudl.lib.cam.ac.uk/iiif/MS-II-00004-00026.json") 
vL00 = ig.getNNEmbedding(imL03) 
fL01,fL02 = ig.reduceDims(vL00) 
_ = ig.scatterImages(imL03,fL01,fL02)
# Out:
# ...
#   Cloning https://github.com/leoimpett/pyimagegraph to /tmp/pip-req-build-nyf3lgjv
#   Running command git clone -q https://github.com/leoimpett/pyimagegraph /tmp/pip-req-build-nyf3lgjv
# ...
#   Created wheel for imagegraph: filename=imagegraph-0.0.1-cp36-none-any.whl size=26424 sha256=6e108d44fe8406413a527732b81fc531b0578532ec0231825f6d01036b5493b1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zmrmc0yc/wheels/7b/78/0e/fae6d5b313f1b1e04d581776fa9cd17893a07e3a07d6a8b028
# Successfully built imagegraph
# ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# downloading images from IIIF manifest...
# 100%|██████████| 174/174 [01:20<00:00,  2.15it/s]
# ...
#
# Successfully downloaded inception-2015-12-05.tgz 88931400 bytes.
# ...
